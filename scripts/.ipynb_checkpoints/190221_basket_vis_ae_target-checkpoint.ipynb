# %%
import neuronencodings as ne
from neuronencodings import pred as ne_pred
from neuronencodings.data import transform as ne_transform
import meshpred
from meshpred import unsupervised
from meshparty import trimesh_io
from sklearn import manifold

import denseanalysis
# Out:
# sqlalchemy_database_uri: postgresql://postgres:welcometothematrix@35.196.105.34/postgres
#
#
#
# 2019-04-15 10:59:12,478 INFO sqlalchemy.engine.base.Engine select version()
# 2019-04-15 10:59:12,479 INFO sqlalchemy.engine.base.Engine {}
# 2019-04-15 10:59:12,524 INFO sqlalchemy.engine.base.Engine select current_schema()
# 2019-04-15 10:59:12,525 INFO sqlalchemy.engine.base.Engine {}
# 2019-04-15 10:59:12,567 INFO sqlalchemy.engine.base.Engine SELECT CAST('test plain returns' AS VARCHAR(60)) AS anon_1
# 2019-04-15 10:59:12,568 INFO sqlalchemy.engine.base.Engine {}
# 2019-04-15 10:59:12,590 INFO sqlalchemy.engine.base.Engine SELECT CAST('test unicode returns' AS VARCHAR(60)) AS anon_1
# 2019-04-15 10:59:12,591 INFO sqlalchemy.engine.base.Engine {}
# 2019-04-15 10:59:12,633 INFO sqlalchemy.engine.base.Engine show standard_conforming_strings
# 2019-04-15 10:59:12,634 INFO sqlalchemy.engine.base.Engine {}
# 2019-04-15 10:59:12,677 INFO sqlalchemy.engine.base.Engine select relname from pg_class c join pg_namespace n on n.oid=c.relnamespace where pg_catalog.pg_table_is_visible(c.oid) and relname=%(name)s
# 2019-04-15 10:59:12,678 INFO sqlalchemy.engine.base.Engine {'name': 'analysisversion'}
# 2019-04-15 10:59:12,701 INFO sqlalchemy.engine.base.Engine select relname from pg_class c join pg_namespace n on n.oid=c.relnamespace where pg_catalog.pg_table_is_visible(c.oid) and relname=%(name)s
# 2019-04-15 10:59:12,701 INFO sqlalchemy.engine.base.Engine {'name': 'analysistables'}
# 2019-04-15 10:59:12,724 INFO sqlalchemy.engine.base.Engine select relname from pg_class c join pg_namespace n on n.oid=c.relnamespace where pg_catalog.pg_table_is_visible(c.oid) and relname=%(name)s
# 2019-04-15 10:59:12,725 INFO sqlalchemy.engine.base.Engine {'name': 'cellsegment'}
# 2019-04-15 10:59:12,747 INFO sqlalchemy.engine.base.Engine select relname from pg_class c join pg_namespace n on n.oid=c.relnamespace where pg_catalog.pg_table_is_visible(c.oid) and relname=%(name)s
# 2019-04-15 10:59:12,748 INFO sqlalchemy.engine.base.Engine {'name': 'neuroncompartment'}
# Connecting svenmd@datajoint.ninai.org:3306
# sqlalchemy_database_uri: postgresql://postgres:welcometothematrix@35.196.105.34/postgres
#
#
#
# 2019-04-15 10:59:17,086 INFO sqlalchemy.engine.base.Engine select version()
# 2019-04-15 10:59:17,087 INFO sqlalchemy.engine.base.Engine {}
# 2019-04-15 10:59:17,128 INFO sqlalchemy.engine.base.Engine select current_schema()
# 2019-04-15 10:59:17,129 INFO sqlalchemy.engine.base.Engine {}
# 2019-04-15 10:59:17,170 INFO sqlalchemy.engine.base.Engine SELECT CAST('test plain returns' AS VARCHAR(60)) AS anon_1
# 2019-04-15 10:59:17,171 INFO sqlalchemy.engine.base.Engine {}
# 2019-04-15 10:59:17,193 INFO sqlalchemy.engine.base.Engine SELECT CAST('test unicode returns' AS VARCHAR(60)) AS anon_1
# 2019-04-15 10:59:17,194 INFO sqlalchemy.engine.base.Engine {}
# 2019-04-15 10:59:17,235 INFO sqlalchemy.engine.base.Engine show standard_conforming_strings
# 2019-04-15 10:59:17,236 INFO sqlalchemy.engine.base.Engine {}
# 2019-04-15 10:59:17,278 INFO sqlalchemy.engine.base.Engine select relname from pg_class c join pg_namespace n on n.oid=c.relnamespace where pg_catalog.pg_table_is_visible(c.oid) and relname=%(name)s
# 2019-04-15 10:59:17,279 INFO sqlalchemy.engine.base.Engine {'name': 'analysisversion'}
# 2019-04-15 10:59:17,301 INFO sqlalchemy.engine.base.Engine select relname from pg_class c join pg_namespace n on n.oid=c.relnamespace where pg_catalog.pg_table_is_visible(c.oid) and relname=%(name)s
# 2019-04-15 10:59:17,302 INFO sqlalchemy.engine.base.Engine {'name': 'analysistables'}
# 2019-04-15 10:59:17,324 INFO sqlalchemy.engine.base.Engine select relname from pg_class c join pg_namespace n on n.oid=c.relnamespace where pg_catalog.pg_table_is_visible(c.oid) and relname=%(name)s
# 2019-04-15 10:59:17,325 INFO sqlalchemy.engine.base.Engine {'name': 'cellsegment'}
# 2019-04-15 10:59:17,347 INFO sqlalchemy.engine.base.Engine select relname from pg_class c join pg_namespace n on n.oid=c.relnamespace where pg_catalog.pg_table_is_visible(c.oid) and relname=%(name)s
# 2019-04-15 10:59:17,348 INFO sqlalchemy.engine.base.Engine {'name': 'neuroncompartment'}

# %%
from meshparty import trimesh_io, iterator

# %%
import numpy as np
import ipyvolume.pylab as p3
import ipyvolume as ipv
import torch
from torch.nn import functional as F

from sklearn import decomposition, cluster
from matplotlib import pyplot as plt

# %%
# %matplotlib inline

# %%
mesh_meta = meshpred.mesh_meta_dict["pinky100"]

# %% [markdown]
# # Load model

# %%
model_dir = "/usr/people/svenmd/seungmount/research/nick_and_sven/models_sven"
model_path = f"{model_dir}/pinky100_baskets_ae_500_1000_local_nonorm_nobn_v1000/models/model_100000.chkpt"

# %%
model, model_params = ne.utils.load_autoencoder_from_file(model_path, gpu=2)

n_pts = model_params["n_points"]
sample_n_pts = model_params["sample_n_points"]
batch_size = model_params["batch_size"]

# %%
print(np.sum(model.mlp1.conv3.weight.data.cpu().numpy(), axis=1).shape)
plt.hist(np.sum(model.mlp1.conv3.weight.data.cpu().numpy(), axis=1))
plt.show()
plt.hist(np.sum(np.abs(model.mlp1.conv3.weight.data.cpu().numpy()), axis=1))
# Out:
# (24, 1)
# (array([1., 0., 3., 4., 2., 4., 4., 4., 0., 2.]),
#  array([10.4642105, 12.875618 , 15.287025 , 17.698433 , 20.10984  ,
#         22.521248 , 24.932655 , 27.344063 , 29.75547  , 32.166878 ,
#         34.578285 ], dtype=float32),
#  <a list of 10 Patch objects>)

# %%
print(np.sum(model.mlp2.layer1.weight.data.cpu().numpy(), axis=0).shape)
plt.hist(np.sum(model.mlp2.layer1.weight.data.cpu().numpy(), axis=0), bins=16)
# Out:
# (24,)
# (array([2., 0., 0., 1., 3., 1., 2., 2., 4., 2., 2., 1., 2., 1., 0., 1.]),
#  array([-4.0973816 , -3.7082622 , -3.319143  , -2.9300237 , -2.5409045 ,
#         -2.1517851 , -1.7626659 , -1.3735466 , -0.98442733, -0.59530807,
#         -0.20618877,  0.18293051,  0.5720498 ,  0.96116906,  1.3502884 ,
#          1.7394077 ,  2.128527  ], dtype=float32),
#  <a list of 16 Patch objects>)

# %% [markdown]
# # Predict output

# %%
basket_df = denseanalysis.adle.query_cell_types("morph_basket_types_manual")
seg_ids = np.array(basket_df[["pt_root_id"]], dtype=np.uint64).squeeze()
labels = np.array(basket_df[["cell_type"]]).squeeze()

pyc_ids = denseanalysis.adle.query_cell_types("soma_valence", cell_type_include_filter=["e"], return_only_ids=True)

pancake_df = denseanalysis.adle.query_cell_types("morph_pancake_types_manual")
pancake_ids = np.array(pancake_df[np.array(pancake_df[["cell_type"]] != "no")][["pt_root_id"]], dtype=np.uint64).squeeze()

seg_ids = np.concatenate([seg_ids, pancake_ids])
labels = np.concatenate([labels, ["NewPancakes"] * len(pancake_ids)])
# Out:
# 2019-04-15 10:59:30,577 INFO sqlalchemy.engine.base.Engine select relname from pg_class c join pg_namespace n on n.oid=c.relnamespace where pg_catalog.pg_table_is_visible(c.oid) and relname=%(name)s
# 2019-04-15 10:59:30,578 INFO sqlalchemy.engine.base.Engine {'name': 'SELECT morph_basket_types_manual.id, morph_basket_types_manual.valid, morph_basket_types_manual.classification_system, morph_basket_types_manual.cell ... (36 characters truncated) ... manual.pt_position) AS pt_position, morph_basket_types_manual.pt_supervoxel_id, morph_basket_types_manual.pt_root_id \nFROM morph_basket_types_manual'}
# 2019-04-15 10:59:30,641 INFO sqlalchemy.engine.base.Engine SELECT morph_basket_types_manual.id, morph_basket_types_manual.valid, morph_basket_types_manual.classification_system, morph_basket_types_manual.cell_type, ST_AsEWKB(morph_basket_types_manual.pt_position) AS pt_position, morph_basket_types_manual.pt_supervoxel_id, morph_basket_types_manual.pt_root_id
# FROM morph_basket_types_manual
# 2019-04-15 10:59:30,642 INFO sqlalchemy.engine.base.Engine {}
# 2019-04-15 10:59:31,117 INFO sqlalchemy.engine.base.Engine select relname from pg_class c join pg_namespace n on n.oid=c.relnamespace where pg_catalog.pg_table_is_visible(c.oid) and relname=%(name)s
# 2019-04-15 10:59:31,118 INFO sqlalchemy.engine.base.Engine {'name': 'SELECT pt_root_id \nFROM soma_valence \nWHERE soma_valence.cell_type IN (:cell_type_1)'}
# 2019-04-15 10:59:31,179 INFO sqlalchemy.engine.base.Engine SELECT pt_root_id
# FROM soma_valence
# WHERE soma_valence.cell_type IN (%(cell_type_1)s)
# 2019-04-15 10:59:31,180 INFO sqlalchemy.engine.base.Engine {'cell_type_1': 'e'}
# 2019-04-15 10:59:31,419 INFO sqlalchemy.engine.base.Engine select relname from pg_class c join pg_namespace n on n.oid=c.relnamespace where pg_catalog.pg_table_is_visible(c.oid) and relname=%(name)s
# 2019-04-15 10:59:31,420 INFO sqlalchemy.engine.base.Engine {'name': 'SELECT morph_pancake_types_manual.id, morph_pancake_types_manual.valid, morph_pancake_types_manual.classification_system, morph_pancake_types_manual. ... (44 characters truncated) ... ual.pt_position) AS pt_position, morph_pancake_types_manual.pt_supervoxel_id, morph_pancake_types_manual.pt_root_id \nFROM morph_pancake_types_manual'}
# 2019-04-15 10:59:31,482 INFO sqlalchemy.engine.base.Engine SELECT morph_pancake_types_manual.id, morph_pancake_types_manual.valid, morph_pancake_types_manual.classification_system, morph_pancake_types_manual.cell_type, ST_AsEWKB(morph_pancake_types_manual.pt_position) AS pt_position, morph_pancake_types_manual.pt_supervoxel_id, morph_pancake_types_manual.pt_root_id
# FROM morph_pancake_types_manual
# 2019-04-15 10:59:31,483 INFO sqlalchemy.engine.base.Engine {}

# %%
mesh = mesh_meta.mesh(seg_id=seg_ids[10])

it = iterator.LocalViewIterator(mesh, n_pts, order="random",
                                sample_n_points=sample_n_pts,
                                batch_size=batch_size,
                                adaptnorm=False,
                                fisheye=False,
                                pc_align=True,
                                verbose=False, 
                                pc_norm=False)

# %%
try:
    views, centers = next(it)
    views = ne_transform.norm_to_unit_sphere_many(views)
except:
    it = iterator.LocalViewIterator(mesh, n_pts, order="random",
                                    sample_n_points=1000,
                                    batch_size=batch_size,
                                    adaptnorm=False,
                                    fisheye=False,
                                    pc_align=True,
                                    verbose=False, 
                                    pc_norm=False)
    views, centers = next(it)
    views = ne_transform.norm_to_unit_sphere_many(views)
    
    print(views.shape)

points_tensor = torch.from_numpy(views).cuda()
with torch.no_grad():
    pred_views_tensor, fs = model.forward(points_tensor)
    
pred_views = pred_views_tensor.data.cpu().numpy()


print(np.mean(fs.data.cpu().numpy()>0, axis=0))
print(torch.var(fs, dim=0))

fig = p3.figure(width=1024, height=1024)

X, Y, Z = np.array(views[0].T*1000)
ipv.scatter(X, Y, Z, marker='sphere', color=".2", size=1)

X, Y, Z = np.array(pred_views[0].T*1000)
ipv.scatter(X, Y, Z, marker='sphere', color="red", size=1)

# fs[:, np.where(np.mean(fs.data.cpu().numpy()>0, axis=0) == 0)[0]] = 1
# with torch.no_grad():
#     batch_size = fs.size()[0]
#     rec = model.output(model.mlp2(fs)).view(batch_size, model.n_pts, model.pt_dim)

# rec = rec.data.cpu().numpy()
# X, Y, Z = np.array(rec[0].T*1000)
# ipv.scatter(X, Y, Z, marker='sphere', color="blue", size=1)

# X, Y, Z = np.array(pred_views[2].T*1000)
# ipv.scatter(X, Y, Z, marker='sphere', color="yellow", size=1)
# ipv.scatter(X, Y, Z, marker='sphere', color="red", size= l / np.max(l) * 2)
# ipv.scatter(X, Y, Z, marker='sphere', color="red", size= s / np.max(s) * 2)

ipv.squarelim()
ipv.show()
# Out:
# Views took 0.261s
# [0.975 1.    0.975 1.    0.975 1.    0.975 1.    1.    0.975 0.    1.
#  1.    1.    1.    0.975 0.975 1.    1.    1.    0.975 1.    1.    1.   ]
# tensor([ 0.0316,  0.0120,  0.0195,  0.0337,  0.0396,  0.0238,  0.1126,
#          0.0523,  0.0732,  0.0336,  0.0000,  0.0711,  0.0870,  0.0381,
#          0.0254,  0.0248,  0.0619,  0.0431,  0.0835,  0.0572,  0.0606,
#          0.0198,  0.0501,  0.1221], device='cuda:0')
# VBox(children=(Figure(camera=PerspectiveCamera(fov=46.0, position=(0.0, 0.0, 2.0), quaternion=(0.0, 0.0, 0.0, …

# %% [markdown]
# ## Latent encoding

# %% [markdown]
# ### Prediction

# %%
cell_views = []
cell_view_seg_ids = []
cell_view_labels = []
for i, (seg_id, label) in enumerate(zip(seg_ids, labels)): 
    print(f"{i}/{len(seg_ids)} -- {seg_id}")
    mesh = mesh_meta.mesh(seg_id=seg_id, merge_large_components=False)
    
    if mesh.n_vertices < n_pts:
        continue
        
    views, centers = ne.pred.encode_mesh_by_views(model, mesh,
                                                  n_points=n_pts,
                                                  sample_n_points=n_pts,
                                                  fisheye=False,
                                                  batch_size=batch_size,
                                                  order="random",
                                                  pc_align=True,
                                                  method="kdtree",
                                                  max_samples=500)
    cell_views.append(views)
    cell_view_seg_ids.append(seg_id)
    cell_view_labels.append(label)
    
views_flat = np.concatenate([c for c in cell_views if len(c) > 0])
cell_view_seg_ids = np.array(cell_view_seg_ids)
cell_view_labels = np.array(cell_view_labels)
# Out:
# 0/342 -- 648518346349468866
# Views took 0.832s
# Views took 0.275s
# Views took 0.093s
# Views took 0.239s
# Views took 0.079s
# Views took 0.400s
# Views took 0.236s
# Views took 0.305s
# Views took 0.187s
# Views took 0.631s
# Views took 0.197s
# Views took 0.025s
# 1/342 -- 648518346349378422
# Views took 1.188s
# Views took 0.071s
# Views took 0.070s
# Views took 0.309s
# Views took 0.067s
# Views took 0.074s
# Views took 0.075s
# Views took 0.067s
# Views took 0.065s
# Views took 0.069s
# Views took 0.059s
# Views took 0.057s
# 2/342 -- 648518346342807581
# Views took 0.403s
# Views took 0.454s
# Views took 0.165s
# Views took 0.238s
# Views took 0.120s
# Views took 0.078s
# Views took 0.273s
# Views took 0.418s
# Views took 0.293s
# Views took 0.214s
# Views took 0.963s
# Views took 0.141s
# Views took 0.173s
# 3/342 -- 648518346341397888
# Views took 0.396s
# Views took 0.454s
# Views took 0.462s
# Views took 0.190s
# Views took 0.370s
# Views took 0.189s
# Views took 0.284s
# Views took 0.111s
# Views took 0.164s
# Views took 0.105s
# Views took 0.221s
# Views took 0.086s
# Views took 0.103s
# 4/342 -- 648518346342807581
# Views took 0.191s
# Views took 0.138s
# Views took 0.276s
# Views took 0.099s
# Views took 0.086s
# Views took 0.087s
# Views took 0.108s
# Views took 0.060s
# Views took 0.337s
# Views took 0.112s
# Views took 0.056s
# Views took 0.064s
# Views took 0.066s
# 5/342 -- 648518346341359062
# Views took 0.102s
# Views took 0.309s
# Views took 0.069s
# Views took 0.056s
# Views took 0.074s
# Views took 0.096s
# Views took 0.110s
# 6/342 -- 648518346349507417
# Views took 0.456s
# Views took 0.074s
# Views took 0.069s
# Views took 0.056s
# 7/342 -- 648518346349472797
# Views took 0.236s
# Views took 0.381s
# Views took 0.605s
# Views took 0.136s
# Views took 0.082s
# Views took 0.101s
# Views took 0.107s
# Views took 0.173s
# Views took 0.270s
# Views took 0.155s
# Views took 0.147s
# Views took 0.117s
# Views took 0.057s
# 8/342 -- 648518346341369711
# Views took 0.227s
# Views took 0.055s
# Views took 0.059s
# Views took 0.114s
# Views took 0.062s
# 9/342 -- 648518346341397888
# Views took 0.228s
# Views took 0.361s
# Views took 0.223s
# Views took 0.125s
# Views took 0.321s
# Views took 0.013s
# 177/342 -- 648518346349496369
# Views took 0.390s
# Views took 0.234s
# Views took 0.305s
# Views took 0.136s
# 178/342 -- 648518346349498892
# Views took 0.117s
# Views took 0.225s
# Views took 0.136s
# Views took 0.357s
# Views took 0.086s
# 179/342 -- 648518346349496419
# Views took 0.156s
# Views took 0.187s
# Views took 0.070s
# Views took 0.048s
# Views took 0.057s
# Views took 0.061s
# 180/342 -- 648518346349496457
# Views took 0.852s
# Views took 0.179s
# Views took 0.135s
# Views took 0.089s
# Views took 0.509s
# Views took 0.170s
# Views took 0.170s
# Views took 0.112s
# Views took 0.060s
# Views took 0.191s
# Views took 0.066s
# Views took 0.076s
# Views took 0.242s
# 181/342 -- 648518346349496490
# Views took 0.554s
# Views took 0.107s
# Views took 0.364s
# Views took 0.259s
# Views took 0.155s
# Views took 0.055s
# Views took 0.752s
# Views took 0.058s
# Views took 0.065s
# Views took 0.046s
# 182/342 -- 648518346349374565
# Views took 0.622s
# Views took 0.066s
# Views took 0.079s
# Views took 0.502s
# Views took 0.290s
# Views took 0.121s
# Views took 0.091s
# 183/342 -- 648518346349496506

# %% [markdown]
# ### Naive combination

# %%
bins = [np.histogram(views_flat[:, i], bins=5)[1] for i in range(len(views_flat[0]))]

cell_view_summary = []
for cell_view in cell_views:
    if len(cell_view) == 0:
        continue
        
    cell_view = np.array(cell_view)
        
    hist_feats = []
#     for i_dim in range(len(cell_view[0])):
#         hist_feats.extend(np.histogram(cell_view[:, i_dim], bins=bins[i_dim])[0])
    
    hist_feats = np.array(hist_feats)
    cell_view_summary.append(np.concatenate([np.min(cell_view, axis=0), 
                                             np.max(cell_view, axis=0), 
                                             np.std(cell_view, axis=0), 
                                             np.mean(cell_view, axis=0), 
                                             np.median(cell_view, axis=0),
                                             hist_feats]))
    
cell_view_summary = np.array(cell_view_summary)

# %%
features_t, explained_variance_ratio_, pca = unsupervised.get_pca_components(cell_view_summary)

for dim in range(0, 9):
    fig = plt.figure(figsize=(12, 12))
    
    for c in np.unique(cell_view_labels):
        plt.scatter(features_t[cell_view_labels == c, dim], features_t[cell_view_labels == c, dim+1], alpha=.7, label=c)
    plt.legend()
    plt.show()
# Out:
# [0.32923003 0.10872894 0.06484319 0.04855173 0.03754544 0.02843962
#  0.02480779 0.02132405 0.01867819 0.01739334]

# %%
features_t, explained_variance_ratio_, pca = unsupervised.get_pca_components(cell_view_summary)

cell_view_summary_n = np.array(cell_view_summary).copy()
std = np.std(cell_view_summary_n, axis=0)[None]
std[std == 0] = 1
cell_view_summary_n /= std
cell_view_summary_n -= np.nanmean(cell_view_summary_n, axis=0)[None]
kmeans = cluster.KMeans(n_clusters=8)
classes = kmeans.fit_predict(cell_view_summary_n)

for dim in range(0, 10, 2):
    fig = plt.figure(figsize=(12, 12))
    
    for c in np.unique(classes):
        plt.scatter(features_t[classes == c, dim], features_t[classes == c, dim+1], alpha=.7)
    plt.show()
# Out:
# [0.26621341 0.17304058 0.08929618 0.05033527 0.03309601 0.02663339
#  0.02277359 0.01977799 0.01562968 0.01463837]

# %% [markdown]
# ### All views

# %%
features_t, explained_variance_ratio_, pca = unsupervised.get_pca_components(views_flat)

for dim in range(0, 10, 2):
    fig = plt.figure(figsize=(12, 12))
    plt.scatter(features_t[:, dim], features_t[:, dim+1], alpha=.1)
    plt.show()
# Out:
# [0.46162174 0.1070295  0.0825395  0.05906104 0.04421983 0.04022285
#  0.03077552 0.02318065 0.02139286 0.01986793]

# %% [markdown]
# ### Smarter ways of combining views

# %%
features_t, explained_variance_ratio_, pca = unsupervised.get_pca_components(views_flat, normed=False)
bins = [np.histogram(features_t[:, i], bins=5)[1] for i in range(len(features_t[0]))]

cell_view_summary = []

loc = 0
for cell_view in cell_views:
    if len(cell_view) == 0:
        continue
        
    cell_view_t = features_t[loc: loc + len(cell_view)]

    hist_feats = []
    for i_dim in range(len(cell_view_t[0])):
        hist_feats.extend(np.histogram(cell_view_t[:, i_dim], bins=bins[i_dim])[0])
    
    hist_feats = np.array(hist_feats)
    
    corr_feats = []
    corrcoef = np.corrcoef(cell_view_t)
    corrs = corrcoef[np.tril_indices_from(corrcoef, k=-1)]
    corr_feats.append(np.mean(corrs))
    corr_feats.append(np.std(corrs))
    corr_feats.append(np.median(corrs))
#     corr_feats.extend(np.histogram(corrs, bins=np.linspace(-1, 1, 11))[0])
    
    cell_view_summary.append(np.concatenate([np.min(cell_view_t, axis=0), 
                                             np.max(cell_view_t, axis=0), 
                                             np.std(cell_view_t, axis=0), 
                                             np.mean(cell_view_t, axis=0),
                                             np.median(cell_view_t, axis=0),
                                             corr_feats,
                                             hist_feats]))
    loc += len(cell_view)
    
cell_view_summary = np.array(cell_view_summary)

features_t, explained_variance_ratio_, pca = unsupervised.get_pca_components(cell_view_summary, normed=False)

for dim in range(0, 9):
    fig = plt.figure(figsize=(12, 12))
    
    for c in np.unique(cell_view_labels):
        if c == "new_pancakes":
            continue
        plt.scatter(features_t[cell_view_labels == c, dim], features_t[cell_view_labels == c, dim+1], alpha=.7, label=c)
    plt.legend()
    plt.show()
# Out:
# [0.46162157 0.10702945 0.08253958 0.05906112 0.04421985 0.04022291
#  0.03077556 0.0231806  0.02139275 0.01986797]
# [0.3290822  0.10873592 0.06477666 0.04855091 0.03755422 0.02845359
#  0.02480216 0.02128339 0.01869371 0.01742545]

# %% [markdown]
# ## Excitatory vs inhibitory cell / synapse encodings

# %%
ie_mesh_meta = trimesh_io.MeshMeta(cv_path=meshpred.cv_path_pinky100,
                                   disk_cache_path=meshpred.mesh_dir_pinky100, cache_size=1000)

# %%
basket_df = denseanalysis.adle.query_cell_types("morph_basket_types_manual")
basket_ids = np.array(basket_df[["pt_root_id"]], dtype=np.uint64).squeeze()

pyc_ids = denseanalysis.adle.query_cell_types("soma_valence",
                                              cell_type_include_filter=["e"],
                                              return_only_ids=True,
                                              exclude_zero_root_ids=True)

basket_syns = denseanalysis.adle.query_synapses("pni_synapses_i3", pre_ids=basket_ids)
pyc_syns = denseanalysis.adle.query_synapses("pni_synapses_i3", pre_ids=pyc_ids)
# Out:
# 2019-03-03 22:45:24,078 INFO sqlalchemy.engine.base.Engine select relname from pg_class c join pg_namespace n on n.oid=c.relnamespace where pg_catalog.pg_table_is_visible(c.oid) and relname=%(name)s
# 2019-03-03 22:45:24,078 INFO sqlalchemy.engine.base.Engine {'name': 'SELECT pinky100_morph_basket_types_manual_v57.id, pinky100_morph_basket_types_manual_v57.valid, pinky100_morph_basket_types_manual_v57.classification ... (140 characters truncated) ... ky100_morph_basket_types_manual_v57.pt_supervoxel_id, pinky100_morph_basket_types_manual_v57.pt_root_id \nFROM pinky100_morph_basket_types_manual_v57'}
# 2019-03-03 22:45:24,141 INFO sqlalchemy.engine.base.Engine SELECT pinky100_morph_basket_types_manual_v57.id, pinky100_morph_basket_types_manual_v57.valid, pinky100_morph_basket_types_manual_v57.classification_system, pinky100_morph_basket_types_manual_v57.cell_type, ST_AsEWKB(pinky100_morph_basket_types_manual_v57.pt_position) AS pt_position, pinky100_morph_basket_types_manual_v57.pt_supervoxel_id, pinky100_morph_basket_types_manual_v57.pt_root_id
# FROM pinky100_morph_basket_types_manual_v57
# 2019-03-03 22:45:24,141 INFO sqlalchemy.engine.base.Engine {}
# 2019-03-03 22:45:24,513 INFO sqlalchemy.engine.base.Engine select relname from pg_class c join pg_namespace n on n.oid=c.relnamespace where pg_catalog.pg_table_is_visible(c.oid) and relname=%(name)s
# 2019-03-03 22:45:24,514 INFO sqlalchemy.engine.base.Engine {'name': 'SELECT pt_root_id \nFROM pinky100_soma_valence_v57 \nWHERE pinky100_soma_valence_v57.cell_type IN (:cell_type_1) AND pinky100_soma_valence_v57.pt_root_id NOT IN (:pt_root_id_1)'}
# 2019-03-03 22:45:24,575 INFO sqlalchemy.engine.base.Engine SELECT pt_root_id
# FROM pinky100_soma_valence_v57
# WHERE pinky100_soma_valence_v57.cell_type IN (%(cell_type_1)s) AND pinky100_soma_valence_v57.pt_root_id NOT IN (%(pt_root_id_1)s)
# 2019-03-03 22:45:24,576 INFO sqlalchemy.engine.base.Engine {'cell_type_1': 'e', 'pt_root_id_1': 0}
# 2019-03-03 22:45:24,824 INFO sqlalchemy.engine.base.Engine select relname from pg_class c join pg_namespace n on n.oid=c.relnamespace where pg_catalog.pg_table_is_visible(c.oid) and relname=%(name)s
# 2019-03-03 22:45:24,824 INFO sqlalchemy.engine.base.Engine {'name': 'SELECT pinky100_pni_synapses_i3_v57.id, pinky100_pni_synapses_i3_v57.valid, ST_AsEWKB(pinky100_pni_synapses_i3_v57.pre_pt_position) AS pre_pt_positio ... (4948 characters truncated) ... pre_pt_root_id_219, :pre_pt_root_id_220, :pre_pt_root_id_221, :pre_pt_root_id_222, :pre_pt_root_id_223) AND pinky100_pni_synapses_i3_v57.valid = true'}
# 2019-03-03 22:45:24,889 INFO sqlalchemy.engine.base.Engine SELECT pinky100_pni_synapses_i3_v57.id, pinky100_pni_synapses_i3_v57.valid, ST_AsEWKB(pinky100_pni_synapses_i3_v57.pre_pt_position) AS pre_pt_position, pinky100_pni_synapses_i3_v57.pre_pt_supervoxel_id, pinky100_pni_synapses_i3_v57.pre_pt_root_id, ST_AsEWKB(pinky100_pni_synapses_i3_v57.ctr_pt_position) AS ctr_pt_position, ST_AsEWKB(pinky100_pni_synapses_i3_v57.post_pt_position) AS post_pt_position, pinky100_pni_synapses_i3_v57.post_pt_supervoxel_id, pinky100_pni_synapses_i3_v57.post_pt_root_id, pinky100_pni_synapses_i3_v57.size
# FROM pinky100_pni_synapses_i3_v57
# WHERE pinky100_pni_synapses_i3_v57.pre_pt_root_id IN (%(pre_pt_root_id_1)s, %(pre_pt_root_id_2)s, %(pre_pt_root_id_3)s, %(pre_pt_root_id_4)s, %(pre_pt_root_id_5)s, %(pre_pt_root_id_6)s, %(pre_pt_root_id_7)s, %(pre_pt_root_id_8)s, %(pre_pt_root_id_9)s, %(pre_pt_root_id_10)s, %(pre_pt_root_id_11)s, %(pre_pt_root_id_12)s, %(pre_pt_root_id_13)s, %(pre_pt_root_id_14)s, %(pre_pt_root_id_15)s, %(pre_pt_root_id_16)s, %(pre_pt_root_id_17)s, %(pre_pt_root_id_18)s, %(pre_pt_root_id_19)s, %(pre_pt_root_id_20)s, %(pre_pt_root_id_21)s, %(pre_pt_root_id_22)s, %(pre_pt_root_id_23)s, %(pre_pt_root_id_24)s, %(pre_pt_root_id_25)s, %(pre_pt_root_id_26)s, %(pre_pt_root_id_27)s, %(pre_pt_root_id_28)s, %(pre_pt_root_id_29)s, %(pre_pt_root_id_30)s, %(pre_pt_root_id_31)s, %(pre_pt_root_id_32)s, %(pre_pt_root_id_33)s, %(pre_pt_root_id_34)s, %(pre_pt_root_id_35)s, %(pre_pt_root_id_36)s, %(pre_pt_root_id_37)s, %(pre_pt_root_id_38)s, %(pre_pt_root_id_39)s, %(pre_pt_root_id_40)s, %(pre_pt_root_id_41)s, %(pre_pt_root_id_42)s, %(pre_pt_root_id_43)s, %(pre_pt_root_id_44)s, %(pre_pt_root_id_45)s, %(pre_pt_root_id_46)s, %(pre_pt_root_id_47)s, %(pre_pt_root_id_48)s, %(pre_pt_root_id_49)s, %(pre_pt_root_id_50)s, %(pre_pt_root_id_51)s, %(pre_pt_root_id_52)s, %(pre_pt_root_id_53)s, %(pre_pt_root_id_54)s, %(pre_pt_root_id_55)s, %(pre_pt_root_id_56)s, %(pre_pt_root_id_57)s, %(pre_pt_root_id_58)s, %(pre_pt_root_id_59)s, %(pre_pt_root_id_60)s, %(pre_pt_root_id_61)s, %(pre_pt_root_id_62)s, %(pre_pt_root_id_63)s, %(pre_pt_root_id_64)s, %(pre_pt_root_id_65)s, %(pre_pt_root_id_66)s, %(pre_pt_root_id_67)s, %(pre_pt_root_id_68)s, %(pre_pt_root_id_69)s, %(pre_pt_root_id_70)s, %(pre_pt_root_id_71)s, %(pre_pt_root_id_72)s, %(pre_pt_root_id_73)s, %(pre_pt_root_id_74)s, %(pre_pt_root_id_75)s, %(pre_pt_root_id_76)s, %(pre_pt_root_id_77)s, %(pre_pt_root_id_78)s, %(pre_pt_root_id_79)s, %(pre_pt_root_id_80)s, %(pre_pt_root_id_81)s, %(pre_pt_root_id_82)s, %(pre_pt_root_id_83)s, %(pre_pt_root_id_84)s, %(pre_pt_root_id_85)s, %(pre_pt_root_id_86)s, %(pre_pt_root_id_87)s, %(pre_pt_root_id_88)s, %(pre_pt_root_id_89)s, %(pre_pt_root_id_90)s, %(pre_pt_root_id_91)s, %(pre_pt_root_id_92)s, %(pre_pt_root_id_93)s, %(pre_pt_root_id_94)s, %(pre_pt_root_id_95)s, %(pre_pt_root_id_96)s, %(pre_pt_root_id_97)s, %(pre_pt_root_id_98)s, %(pre_pt_root_id_99)s, %(pre_pt_root_id_100)s, %(pre_pt_root_id_101)s, %(pre_pt_root_id_102)s, %(pre_pt_root_id_103)s, %(pre_pt_root_id_104)s, %(pre_pt_root_id_105)s, %(pre_pt_root_id_106)s, %(pre_pt_root_id_107)s, %(pre_pt_root_id_108)s, %(pre_pt_root_id_109)s, %(pre_pt_root_id_110)s, %(pre_pt_root_id_111)s, %(pre_pt_root_id_112)s, %(pre_pt_root_id_113)s, %(pre_pt_root_id_114)s, %(pre_pt_root_id_115)s, %(pre_pt_root_id_116)s, %(pre_pt_root_id_117)s, %(pre_pt_root_id_118)s, %(pre_pt_root_id_119)s, %(pre_pt_root_id_120)s, %(pre_pt_root_id_121)s, %(pre_pt_root_id_122)s, %(pre_pt_root_id_123)s, %(pre_pt_root_id_124)s, %(pre_pt_root_id_125)s, %(pre_pt_root_id_126)s, %(pre_pt_root_id_127)s, %(pre_pt_root_id_128)s, %(pre_pt_root_id_129)s, %(pre_pt_root_id_130)s, %(pre_pt_root_id_131)s, %(pre_pt_root_id_132)s, %(pre_pt_root_id_133)s, %(pre_pt_root_id_134)s, %(pre_pt_root_id_135)s, %(pre_pt_root_id_136)s, %(pre_pt_root_id_137)s, %(pre_pt_root_id_138)s, %(pre_pt_root_id_139)s, %(pre_pt_root_id_140)s, %(pre_pt_root_id_141)s, %(pre_pt_root_id_142)s, %(pre_pt_root_id_143)s, %(pre_pt_root_id_144)s, %(pre_pt_root_id_145)s, %(pre_pt_root_id_146)s, %(pre_pt_root_id_147)s, %(pre_pt_root_id_148)s, %(pre_pt_root_id_149)s, %(pre_pt_root_id_150)s, %(pre_pt_root_id_151)s, %(pre_pt_root_id_152)s, %(pre_pt_root_id_153)s, %(pre_pt_root_id_154)s, %(pre_pt_root_id_155)s, %(pre_pt_root_id_156)s, %(pre_pt_root_id_157)s, %(pre_pt_root_id_158)s, %(pre_pt_root_id_159)s, %(pre_pt_root_id_160)s, %(pre_pt_root_id_161)s, %(pre_pt_root_id_162)s, %(pre_pt_root_id_163)s, %(pre_pt_root_id_164)s, %(pre_pt_root_id_165)s, %(pre_pt_root_id_166)s, %(pre_pt_root_id_167)s, %(pre_pt_root_id_168)s, %(pre_pt_root_id_169)s ...
# 2019-03-03 22:45:24,889 INFO sqlalchemy.engine.base.Engine {'pre_pt_root_id_1': 648518346349468866, 'pre_pt_root_id_2': 648518346349378422, 'pre_pt_root_id_3': 648518346342807581, 'pre_pt_root_id_4': 648518346341397888, 'pre_pt_root_id_5': 648518346342807581, 'pre_pt_root_id_6': 648518346341359062, 'pre_pt_root_id_7': 648518346349507417, 'pre_pt_root_id_8': 648518346349472797, 'pre_pt_root_id_9': 648518346341369711, 'pre_pt_root_id_10': 648518346341397888, 'pre_pt_root_id_11': 648518346342807581, 'pre_pt_root_id_12': 648518346349378422, 'pre_pt_root
'pre_pt_root_id_82': 648518346346314519, 'pre_pt_root_id_83': 648518346349468410, 'pre_pt_root_id_84': 648518346346297367, 'pre_pt_root_id_85': 648518346342793732, 'pre_pt_root_id_86': 648518346342794426, 'pre_pt_root_id_87': 648518346342159112, 'pre_pt_root_id_88': 648518346341374917, 'pre_pt_root_id_89': 648518346341392541, 'pre_pt_root_id_90': 648518346349468864, 'pre_pt_root_id_91': 648518346342931661, 'pre_pt_root_id_92': 648518346346307256, 'pre_pt_root_id_93': 648518346349468863, 'pre_pt_root_id_94': 648518346349387608, 'pre_pt_root_id_95': 648518346342801176, 'pre_pt_root_id_96': 648518346342107299, 'pre_pt_root_ ...
# 2019-03-03 22:45:29,672 INFO sqlalchemy.engine.base.Engine select relname from pg_class c join pg_namespace n on n.oid=c.relnamespace where pg_catalog.pg_table_is_visible(c.oid) and relname=%(name)s
# 2019-03-03 22:45:29,673 INFO sqlalchemy.engine.base.Engine {'name': 'SELECT pinky100_pni_synapses_i3_v57.id, pinky100_pni_synapses_i3_v57.valid, ST_AsEWKB(pinky100_pni_synapses_i3_v57.pre_pt_position) AS pre_pt_positio ... (7195 characters truncated) ... pre_pt_root_id_326, :pre_pt_root_id_327, :pre_pt_root_id_328, :pre_pt_root_id_329, :pre_pt_root_id_330) AND pinky100_pni_synapses_i3_v57.valid = true'}
# 2019-03-03 22:45:29,738 INFO sqlalchemy.engine.base.Engine SELECT pinky100_pni_synapses_i3_v57.id, pinky100_pni_synapses_i3_v57.valid, ST_AsEWKB(pinky100_pni_synapses_i3_v57.pre_pt_position) AS pre_pt_position, pinky100_pni_synapses_i3_v57.pre_pt_supervoxel_id, pinky100_pni_synapses_i3_v57.pre_pt_root_id, ST_AsEWKB(pinky100_pni_synapses_i3_v57.ctr_pt_position) AS ctr_pt_position, ST_AsEWKB(pinky100_pni_synapses_i3_v57.post_pt_position) AS post_pt_position, pinky100_pni_synapses_i3_v57.post_pt_supervoxel_id, pinky100_pni_synapses_i3_v57.post_pt_root_id, pinky100_pni_synapses_i3_v57.size
# FROM pinky100_pni_synapses_i3_v57
# WHERE pinky100_pni_synapses_i3_v57.pre_pt_root_id IN (%(pre_pt_root_id_1)s, %(pre_pt_root_id_2)s, %(pre_pt_root_id_3)s, %(pre_pt_root_id_4)s, %(pre_pt_root_id_5)s, %(pre_pt_root_id_6)s, %(pre_pt_root_id_7)s, %(pre_pt_root_id_8)s, %(pre_pt_root_id_9)s, %(pre_pt_root_id_10)s, %(pre_pt_root_id_11)s, %(pre_pt_root_id_12)s, %(pre_pt_root_id_13)s, %(pre_pt_root_id_14)s, %(pre_pt_root_id_15)s, %(pre_pt_root_id_16)s, %(pre_pt_root_id_17)s, %(pre_pt_root_id_18)s, %(pre_pt_root_id_19)s, %(pre_pt_root_id_20)s, %(pre_pt_root_id_21)s, %(pre_pt_root_id_22)s, %(pre_pt_root_id_23)s, %(pre_pt_root_id_24)s, %(pre_pt_root_id_25)s, %(pre_pt_root_id_26)s, %(pre_pt_root_id_27)s, %(pre_pt_root_id_28)s, %(pre_pt_root_id_29)s, %(pre_pt_root_id_30)s, %(pre_pt_root_id_31)s, %(pre_pt_root_id_32)s, %(pre_pt_root_id_33)s, %(pre_pt_root_id_34)s, %(pre_pt_root_id_35)s, %(pre_pt_root_id_36)s, %(pre_pt_root_id_37)s, %(pre_pt_root_id_38)s, %(pre_pt_root_id_39)s, %(pre_pt_root_id_40)s, %(pre_pt_root_id_41)s, %(pre_pt_root_id_42)s, %(pre_pt_root_id_43)s, %(pre_pt_root_id_44)s, %(pre_pt_root_id_45)s, %(pre_pt_root_id_46)s, %(pre_pt_root_id_47)s, %(pre_pt_root_id_48)s, %(pre_pt_root_id_49)s, %(pre_pt_root_id_50)s, %(pre_pt_root_id_51)s, %(pre_pt_root_id_52)s, %(pre_pt_root_id_53)s, %(pre_pt_root_id_54)s, %(pre_pt_root_id_55)s, %(pre_pt_root_id_56)s, %(pre_pt_root_id_57)s, %(pre_pt_root_id_58)s, %(pre_pt_root_id_59)s, %(pre_pt_root_id_60)s, %(pre_pt_root_id_61)s, %(pre_pt_root_id_62)s, %(pre_pt_root_id_63)s, %(pre_pt_root_id_64)s, %(pre_pt_root_id_65)s, %(pre_pt_root_id_66)s, %(pre_pt_root_id_67)s, %(pre_pt_root_id_68)s, %(pre_pt_root_id_69)s, %(pre_pt_root_id_70)s, %(pre_pt_root_id_71)s, %(pre_pt_root_id_72)s, %(pre_pt_root_id_73)s, %(pre_pt_root_id_74)s, %(pre_pt_root_id_75)s, %(pre_pt_root_id_76)s, %(pre_pt_root_id_77)s, %(pre_pt_root_id_78)s, %(pre_pt_root_id_79)s, %(pre_pt_root_id_80)s, %(pre_pt_root_id_81)s, %(pre_pt_root_id_82)s, %(pre_pt_root_id_83)s, %(pre_pt_root_id_84)s, %(pre_pt_root_id_85)s, %(pre_pt_root_id_86)s, %(pre_pt_root_id_87)s, %(pre_pt_root_id_88)s, %(pre_pt_root_id_89)s, %(pre_pt_root_id_90)s, %(pre_pt_root_id_91)s, %(pre_pt_root_id_92)s, %(pre_pt_root_id_93)s, %(pre_pt_root_id_94)s, %(pre_pt_root_id_95)s, %(pre_pt_root_id_96)s, %(pre_pt_root_id_97)s, %(pre_pt_root_id_98)s, %(pre_pt_root_id_99)s, %(pre_pt_root_id_100)s, %(pre_pt_root_id_101)s, %(pre_pt_root_id_102)s, %(pre_pt_root_id_103)s, %(pre_pt_root_id_104)s, %(pre_pt_root_id_105)s, %(pre_pt_root_id_106)s, %(pre_pt_root_id_107)s, %(pre_pt_root_id_108)s, %(pre_pt_root_id_109)s, %(pre_pt_root_id_110)s, %(pre_pt_root_id_111)s, %(pre_pt_root_id_112)s, %(pre_pt_root_id_113)s, %(pre_pt_root_id_114)s, %(pre_pt_root_id_115)s, %(pre_pt_root_id_116)s, %(pre_pt_root_id_117)s, %(pre_pt_root_id_118)s, %(pre_pt_root_id_119)s, %(pre_pt_root_id_120)s, %(pre_pt_root_id_121)s, %(pre_pt_root_id_122)s, %(pre_pt_root_id_123)s, %(pre_pt_root_id_124)s, %(pre_pt_root_id_125)s, %(pre_pt_root_id_126)s, %(pre_pt_root_id_127)s, %(pre_pt_root_id_128)s, %(pre_pt_root_id_129)s, %(pre_pt_root_id_130)s, %(pre_pt_root_id_131)s, %(pre_pt_root_id_132)s, %(pre_pt_root_id_133)s, %(pre_pt_root_id_134)s, %(pre_pt_root_id_135)s, %(pre_pt_root_id_136)s, %(pre_pt_root_id_137)s, %(pre_pt_root_id_138)s, %(pre_pt_root_id_139)s, %(pre_pt_root_id_140)s, %(pre_pt_root_id_141)s, %(pre_pt_root_id_142)s, %(pre_pt_root_id_143)s, %(pre_pt_root_id_144)s, %(pre_pt_root_id_145)s, %(pre_pt_root_id_146)s, %(pre_pt_root_id_147)s, %(pre_pt_root_id_148)s, %(pre_pt_root_id_149)s, %(pre_pt_root_id_150)s, %(pre_pt_root_id_151)s, %(pre_pt_root_id_152)s, %(pre_pt_root_id_153)s, %(pre_pt_root_id_154)s, %(pre_pt_root_id_155)s, %(pre_pt_root_id_156)s, %(pre_pt_root_id_157)s, %(pre_pt_root_id_158)s, %(pre_pt_root_id_159)s, %(pre_pt_root_id_160)s, %(pre_pt_root_id_161)s, %(pre_pt_root_id_162)s, %(pre_pt_root_id_163)s, %(pre_pt_root_id_164)s, %(pre_pt_root_id_165)s, %(pre_pt_root_id_166)s, %(pre_pt_root_id_167)s, %(pre_pt_root_id_168)s, %(pre_pt_root_id_169)s ...
# 2019-03-03 22:45:29,739 INFO sqlalchemy.engine.base.Engine {'pre_pt_root_id_1': 648518346349499581, 'pre_pt_root_id_2': 648518346349499624, 'pre_pt_root_id_3': 648518346349499636, 'pre_pt_root_id_4': 648518346349499679, 'pre_pt_root_id_5': 648518346349493117, 'pre_pt_root_id_6': 648518346349499680, 'pre_pt_root_id_7': 648518346349499689, 'pre_pt_root_id_8': 648518346349499701, 'pre_pt_root_id_9': 648518346349497094, 'pre_pt_root_id_10': 648518346349478700, 'pre_pt_root_id_11': 648518346349499759, 'pre_pt_root_id_12': 648518346349499773, 'pre_pt_root_id_13': 648518346349499783, 'pre_pt_root_id_14': 648518346349499824, 'pre_pt_root_id_15': 648518346349499828, 'pre_pt_root_id_16': 648518346349499803, 'pre_pt_root_id_17': 648518346349485870, 'pre_pt_root_id_18': 648518346349478431, 'pre_pt_root_id_19': 648518346349499851, 'pre_pt_root_id_20': 648518346349507103, 'pre_pt_root_id_21': 648518346349483124, 'pre_pt_root_id_22': 648518346349490624, 'pre_pt_root_id_23': 648518346349479837, 'pre_pt_root_id_24': 648518346349503717, 'pre_pt_root_id_25': 648518346349496672, 'pre_pt_root_id_26': 648518346349498116, 'pre_pt_root_id_27': 648518346349506770, 'pre_pt_root_id_28': 648518346349490527, 'pre_pt_root_id_29': 648518346349475035, 'pre_pt_root_id_30': 648518346349474703, 'pre_pt_root_id_31': 648518346349473160, 'pre_pt_root_id_32': 648518346349478473, 'pre_pt_root_id_33': 648518346349506803, 'pre_pt_root_id_34': 648518346349500939, 'pre_pt_root_id_35': 648518346349478399, 'pre_pt_root_id_36': 648518346349500324, 'pre_pt_root_id_37': 648518346349470171, 'pre_pt_root_id_38': 648518346349497752, 'pre_pt_root_id_39': 648518346349481574, 'pre_pt_root_id_40': 648518346349473597, 'pre_pt_root_id_41': 648518346349478248, 'pre_pt_root_id_42': 648518346349474146, 'pre_pt_root_id_43': 648518346349505911, 'pre_pt_root_id_44': 648518346349506092, 'pre_pt_root_id_45': 648518346349481014, 'pre_pt_root_id_46': 648518346349490749, 'pre_pt_root_id_47': 648518346349484607, 'pre_pt_root_id_48': 648518346349499852, 'pre_pt_root_id_49': 648518346349499876, 'pre_pt_root_id_50': 648518346349499896, 'pre_pt_root_id_51': 648518346349497759, 'pre_pt_root_id_52': 648518346349499910, 'pre_pt_root_id_53': 648518346349499928, 'pre_pt_root_id_54': 648518346349499939, 'pre_pt_root_id_55': 648518346349500049, 'pre_pt_root_id_56': 648518346349500120, 'pre_pt_root_id_57': 648518346349478197, 'pre_pt_root_id_58': 648518346349507355, 'pre_pt_root_id_59': 648518346349500126, 'pre_pt_root_id_60': 648518346349500138, 'pre_pt_root_id_61': 648518346349501597, 'pre_pt_root_id_62': 648518346349495452, 'pre_pt_root_id_63': 648518346349500139, 'pre_pt_root_id_64': 648518346349500155, 'pre_pt_root_id_65': 648518346349500162, 'pre_pt_root_id_66': 648518346349498051, 'pre_pt_root_id_67': 648518346349500163, 'pre_pt_root_id_68': 648518346349500181, 'pre_pt_root_id_69': 648518346349500277, 'pre_pt_root_id_70': 648518346349504065, 'pre_pt_root_id_71': 648518346349501587, 'pre_pt_root_id_72': 648518346349496103, 'pre_pt_root_id_73': 648518346349503236, 'pre_pt_root_id_74': 648518346349495481, 'pre_pt_root_id_75': 648518346349503643, 'pre_pt_root_id_76': 648518346349498239, 'pre_pt_root_id_77': 648518346349498286, 'pre_pt_root_id_78': 648518346349495971, 'pre_pt_root_id_79': 648518346349496058, 'pre_pt_root_id_80': 648518346349498482, 'pre_pt_root_id_81': 648518346349498406, 'pre_pt_root_id_82': 648518346349494515, 'pre_pt_root_id_83': 648518346349494539, 'pre_pt_root_id_84': 648518346349493106, 'pre_pt_root_id_85': 648518346349501787, 'pre_pt_root_id_86': 648518346349471910, 'pre_pt_root_id_87': 648518346349479479, 'pre_pt_root_id_88': 648518346349479478, 'pre_pt_root_id_89': 648518346349498835, 'pre_pt_root_id_90': 648518346349500725, 'pre_pt_root_id_91': 648518346349503591, 'pre_pt_root_id_92': 648518346349503592, 'pre_pt_root_id_93': 648518346349479573, 'pre_pt_root_id_94': 648518346349483956, 'pre_pt_root_id_95': 648518346349487734, 'pre_pt_root_id_96': 648518346349478330, 'pre_pt_root_ ...

# %%
basket_locs = []
for entry in basket_syns[["pre_pt_root_id", "ctr_pt_position"]].values:
    basket_id = np.uint64(entry[0])
    basket_loc = entry[1]
    
    basket_locs.append([basket_id, basket_loc])
    
pyc_locs = []
for entry in pyc_syns[["pre_pt_root_id", "ctr_pt_position"]].values:
    pyc_id = np.uint64(entry[0])
    pyc_loc = entry[1]
    
    pyc_locs.append([pyc_id, pyc_loc])

# %%
n_pts = 1000
sample_n_pts = 1000

model_path = f"{model_dir}/pinky100_baskets_ae_1000_local_nonorm_nobn_v45/models/model_133500.chkpt"
gpu = 2
bottle_fs = 24
batch_size = 1

model = ne.utils.load_autoencoder("PointNetAE", n_pts=n_pts,
                                  bottle_fs=bottle_fs, chkpt_fname=model_path,
                                  eval_=True, bn=False, gpu=gpu)
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-27-120e52a3b295> in <module>()
#       9 model = ne.utils.load_autoencoder("PointNetAE", n_pts=n_pts,
#      10                                   bottle_fs=bottle_fs, chkpt_fname=model_path,
# ---> 11                                   eval_=True, bn=False, gpu=gpu)
#
# ~/anaconda3/lib/python3.6/site-packages/neuronencodings/utils.py in load_autoencoder(model_name, n_points, pt_dim, bottle_fs, conv_layers, mlp_layers, act, bn, eval_, chkpt_fname, model_dir, chkpt_num, state_dict, gpu, **kwargs)
#      62                       model_dir=model_dir, chkpt_num=chkpt_num,
#      63                       chkpt_fname=chkpt_fname, eval_=eval_,
# ---> 64                       state_dict=state_dict)
#      65
#      66
#
# ~/anaconda3/lib/python3.6/site-packages/neuronencodings/utils.py in load_model(model_name, model_args, model_kwargs, chkpt_fname, model_dir, chkpt_num, eval_, state_dict)
#      39         model.load_state_dict(state_dict)
#      40     elif chkpt_fname is not None:
# ---> 41         model.load_state_dict(torch.load(chkpt_fname))
#      42
#      43     return model
#
# ~/anaconda3/lib/python3.6/site-packages/torch/nn/modules/module.py in load_state_dict(self, state_dict, strict)
#     719         if len(error_msgs) > 0:
#     720             raise RuntimeError('Error(s) in loading state_dict for {}:\n\t{}'.format(
# --> 721                                self.__class__.__name__, "\n\t".join(error_msgs)))
#     722
#     723     def parameters(self):
#
# RuntimeError: Error(s) in loading state_dict for PointNetAE:
# 	While copying the parameter named "output.weight", whose dimensions in the model are torch.Size([7500, 384]) and whose dimensions in the checkpoint are torch.Size([3000, 384]).
# 	While copying the parameter named "output.bias", whose dimensions in the model are torch.Size([7500]) and whose dimensions in the checkpoint are torch.Size([3000]).

# %%
def encode_locs(locs):
    fss = []
    for i_loc, loc in enumerate(locs):
        print(i_loc, loc)
        mesh = ie_mesh_meta.mesh(seg_id=loc[0])
        views = mesh.get_local_view(center_coord=loc[1], n_points=n_pts, sample_n_points=sample_n_pts)[0]
        views = ne_transform.norm_to_unit_sphere_many(views).astype(np.float32)
        points_tensor = torch.from_numpy(views).cuda()
        with torch.no_grad():
            fs = model.forward_global(points_tensor)[0]

        fss.append(fs.data.cpu().numpy()[0])
    return np.array(fss)

# %%
basket_fss = encode_locs(basket_locs[:50])

# %%
pyc_fss = encode_locs(pyc_locs[:50])

# %%
fss = np.concatenate([basket_fss, pyc_fss])
labels = np.concatenate([np.zeros(len(basket_fss), dtype=np.int),
                         np.ones(len(pyc_fss), dtype=np.int)])

# %%
# features_t, explained_variance_ratio_, pca = unsupervised.get_pca_components(fss, normed=True)

features_t = umap.UMAP(min_dist=.1, n_neighbors=10, n_components=3, metric="cosine").fit_transform(fss)

for dim in range(0, 9):
    fig = plt.figure(figsize=(8, 8))
    
    for c in np.unique(labels):
        plt.scatter(features_t[labels == c, dim], features_t[labels == c, dim+1], alpha=.7, label=c)
    
    plt.legend()
    plt.show()
